# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yasListesi=[10,20,30,30,30,40,50,60,70,75]

# %%
kiloListesi=[20,60,80,85,86,87,70,90,95,90]

# %%
numpYasListesi=np.array(yasListesi)
numpKiloListesi=np.array(kiloListesi)

# %%
plt.plot(numpYasListesi,numpKiloListesi,"r")
plt.xlabel("Yas Verisi")
plt.ylabel("Kilo Verisi")
plt.title("Yas ve Kilo Grafiği")
#(x,y,renk)
# Out:
# Text(0.5, 1.0, 'Yas ve Kilo Grafiği')

# %%
numpyDizisi=np.linspace(0,10,20)
numpyDizisi
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2=numpyDizisi**2

# %%
plt.plot(numpyDizisi,numpyDizisi2,"g--")

# %%
plt.subplot(1,2,1)  #1 sıra, 2 kolon, 1.grafik
plt.plot(numpyDizisi,numpyDizisi2,"r--")
plt.subplot(1,2,2)
plt.plot(numpyDizisi2,numpyDizisi,"b*-")

# %% [markdown]
# # figure

# %%
benimFigure=plt.figure()  #bos kanvas
figureAxes=benimFigure.add_axes([0.2,0.2,0.9,0.9])
figureAxes.plot(numpyDizisi,numpyDizisi2,"g")
figureAxes.set_xlabel("x ekseni")
figureAxes.set_ylabel("y ekseni")
figureAxes.set_title("baslik")
# Out:
# Text(0.5, 1.0, 'baslik')

# %%
figure2 = plt.figure()

eksen1=figure2.add_axes([0.1,0.1,0.7,0.7])
eksen2=figure2.add_axes([0.2,0.5,0.2,0.2])

eksen1.plot(numpyDizisi,numpyDizisi2,"g")
eksen1.set_xlabel("X1 ekseni")
eksen1.set_ylabel("y ekseni")
eksen1.set_title("Title1")

eksen2.plot(numpyDizisi2,numpyDizisi,"g")
eksen2.set_xlabel("X2 ekseni")
eksen2.set_ylabel("y2 ekseni")
eksen2.set_title("Title2")
# Out:
# Text(0.5, 1.0, 'Title2')

# %% [markdown]
# # subplots

# %%
(myFigure, myEksen)=plt.subplots()#colums rows sayısı ile özelleştir

# %%
(myFigure, myEksen)=plt.subplots()
myEksen.plot(numpyDizisi,numpyDizisi2,"g")

# %%
(myFigure, myEksenler)=plt.subplots(nrows=1,ncols=2)

for eksen in myEksenler:
    eksen.plot(numpyDizisi,numpyDizisi2,"g")
    eksen.set_xlabel("x")
plt.tight_layout() # grafik arası uzaklık

# %%
newFigure=plt.figure(dpi=100)        #dpi  çözünürlük

yeniEksen=newFigure.add_axes([0.1,0.1,0.9,0.9])
yeniEksen.plot(numpyDizisi,numpyDizisi**2,label="Numpy Dizisi **2")
yeniEksen.plot(numpyDizisi,numpyDizisi**3,label="Numpy Dizisi **3")
yeniEksen.legend(loc=0)   #grafik içindeki tanımlama =1,2,3,...

# %%
newFigure.savefig("newFigure.png",dpi=200)
#kaydetme islemi

# %% [markdown]
# # Gorsellik

# %%
(myNewFigure,newMyEksen)=plt.subplots()
newMyEksen.plot(numpyDizisi,numpyDizisi2,color="#3A95F7")
newMyEksen.plot(numpyDizisi2,numpyDizisi,color="#4FA758")

# %%
(myNewFigure,newMyEksen)=plt.subplots(dpi=100)
newMyEksen.plot(numpyDizisi,numpyDizisi2,color="g",linewidth=1 , linestyle=":")
newMyEksen.plot(numpyDizisi,numpyDizisi2+5,color="r",linewidth=3)
#marker var sonra bakılır

# %% [markdown]
# # Scatter

# %%
plt.scatter(numpyDizisi,numpyDizisi2)

# %% [markdown]
# # histogram

# %%
yeniDizi=np.random.randint(0,100,20)
plt.hist(yeniDizi)
# Out:
# (array([1., 2., 1., 5., 1., 2., 2., 3., 0., 3.]),
#  array([ 0. ,  9.4, 18.8, 28.2, 37.6, 47. , 56.4, 65.8, 75.2, 84.6, 94. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # boxplot

# %%
plt.boxplot(yeniDizi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20159bb8520>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20159bb8be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20159bb8070>],
#  'medians': [<matplotlib.lines.Line2D at 0x201597fc2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x201597fc640>],
#  'means': []}
